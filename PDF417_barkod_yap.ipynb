# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive

# %%
# !pip install aztec-code-generator
# !pip3 install https://github.com/dlenski/aztec_code_generator/archive/master.zip
# !pip install pyStrich
# !!pip install opencv-python
# !pip install barcode-image-composer
# !pip install python-barcode pylibdmtx opencv-python pillow
# !apt-get -qq install -y barcode-image-composer && pip install -U barcode-image-composer
# !pip install argparse
# !pip install imgcomposer
# !pip3 install pylibdmtx
# !sudo apt-get install libdmtx0a
# !pip install pylibdmtx
# !pip install pylibdmtx[scripts]
# !pip install pdf417
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting aztec-code-generator
#   Downloading aztec_code_generator-0.11-py3-none-any.whl (12 kB)
# Installing collected packages: aztec-code-generator
# Successfully installed aztec-code-generator-0.11
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting https://github.com/dlenski/aztec_code_generator/archive/master.zip
#   Downloading https://github.com/dlenski/aztec_code_generator/archive/master.zip
#      - 18.7 kB 1.1 MB/s 0:00:00
#   Preparing metadata (setup.py) ... done
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyStrich
#   Downloading pyStrich-0.8.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.2/981.2 KB 13.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (from pyStrich) (7.1.2)
# Building wheels for collected packages: pyStrich
#   Building wheel for pyStrich (setup.py) ... done
#   Created wheel for pyStrich: filename=pyStrich-0.8-py3-none-any.whl size=1107393 sha256=79d2069658ae998dc6e9f439a01e027ac22010620b8e8447c958d95c293fe906
#   Stored in directory: /root/.cache/pip/wheels/7b/19/71/add9414f3633ad86fd47e0de58c0c577bf9c33ab5da5e20dd9
# Successfully built pyStrich
# Installing collected packages: pyStrich
# Successfully installed pyStrich-0.8
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting barcode-image-composer
#   Downloading barcode_image_composer-1.0.0-py3-none-any.whl (7.5 kB)
# Collecting qrcode
#   Downloading qrcode-7.4.2-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 KB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /usr/local/lib/python3.8/dist-packages (from barcode-image-composer) (7.1.2)
# Collecting python-barcode
#   Downloading python_barcode-0.14.0-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 KB 7.1 MB/s eta 0:00:00
# Collecting pylibdmtx
#   Downloading pylibdmtx-0.1.10-py2.py3-none-any.whl (23 kB)
# Collecting pypng
#   Downloading pypng-0.20220715.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 KB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from qrcode->barcode-image-composer) (4.5.0)
# Installing collected packages: python-barcode, pypng, pylibdmtx, qrcode, barcode-image-composer
# Successfully installed barcode-image-composer-1.0.0 pylibdmtx-0.1.10 pypng-0.20220715.0 python-barcode-0.14.0 qrcode-7.4.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: python-barcode in /usr/local/lib/python3.8/dist-packages (0.14.0)
# Requirement already satisfied: pylibdmtx in /usr/local/lib/python3.8/dist-packages (0.1.10)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.8/dist-packages (4.6.0.66)
# Requirement already satisfied: pillow in /usr/local/lib/python3.8/dist-packages (7.1.2)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.8/dist-packages (from opencv-python) (1.21.6)
# E: Unable to locate package barcode-image-composer
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting argparse
#   Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement imgcomposer (from versions: none)
# ERROR: No matching distribution found for imgcomposer
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pylibdmtx in /usr/local/lib/python3.8/dist-packages (0.1.10)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Package libdmtx0a is not available, but is referred to by another package.
# This may mean that the package is missing, has been obsoleted, or
# is only available from another source
# However the following packages replace it:
#   libdmtx0b
#
# E: Package 'libdmtx0a' has no installation candidate
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pylibdmtx in /usr/local/lib/python3.8/dist-packages (0.1.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pylibdmtx[scripts] in /usr/local/lib/python3.8/dist-packages (0.1.10)
# Requirement already satisfied: Pillow>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from pylibdmtx[scripts]) (7.1.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pdf417
#   Downloading pdf417-0.8.1-py2.py3-none-any.whl (23 kB)
# Installing collected packages: pdf417
# Successfully installed pdf417-0.8.1

# %%
import glob
import cv2
import pandas as pd
import pathlib

from PIL import Image
from pdf417 import encode, render_image, render_svg

# %%
import pandas as pd
import numpy as np

# %%
import csv
rows = []
mesut=1;
with open("/content/drive/MyDrive/pdf malware/dataset2/no.csv", 'r') as file:
    csvreader = csv.reader(file)
    for row in csvreader:
        rows.append(row)
        row1=str(row)
        #print(row)
        codes = encode(row1, columns=10, security_level=8)
        # Generate barcode as image
        image = render_image(codes)  # Pillow Image object
        image.save(f"/content/drive/MyDrive/pdf malware/dataset2/no/no{mesut}.png")
        mesut=mesut+1
        if mesut % 1000 == 0:
          print(mesut)
print(mesut)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 9007
